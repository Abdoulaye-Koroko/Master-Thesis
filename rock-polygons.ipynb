# %%
import json
import urllib.request
import os
from detectron2.structures import BoxMode
from detectron2.data import DatasetCatalog, MetadataCatalog
from detectron2.utils.visualizer import Visualizer
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.utils.visualizer import ColorMode
import cv2
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
def download(json_dir_name):
    json_filenames=os.listdir(json_dir_name)
    print("Téléchargement en cours...")
    for i in range(len(json_filenames)):
        filename =  json_filenames[i]
        try:
            f=open(os.path.join(json_dir_name,filename))
            data=json.load(f)
            carac_image=data["image"]
            image_name= carac_image["original_filename"]
            url= carac_image["url"]
            urllib.request.urlretrieve(url, os.path.join("Dataset",image_name))
        except:
            print("Erreur dans le nom du fichier")
    print ("Téléchargement terminé")

# %%
#download(json_dir_name="rock-darwin")

# %%
def get_rock_dicts(image_dir,json_dir):
    dataset_dicts = []
    json_filenames=os.listdir(json_dir)
    for i in range(len(json_filenames)):
        record = {}
        filename=json_filenames[i]
        try:
            f=open(os.path.join(json_dir,filename))
            data=json.load(f)
        except:
            print(filename,"est corrompu")
            
        carac_image=data["image"]
        image_name= carac_image["original_filename"]
        image_name=os.path.join(image_dir,image_name)
        #print(image_name)
        height, width = cv2.imread(image_name).shape[:2]    
        record["file_name"] = image_name
        record["image_id"] = i
        record["height"] = height
        record["width"] = width
        
        annotations = data["annotations"]
        objs=[]
        for j in range(len(annotations)):
            ann=annotations[j]
            try:
                poly=ann["polygon"]
            except:
                continue
            poly= poly["path"]
            px= [p["x"] for p in poly]
            py= [p["y"] for p in poly]
            poly= [(p["x"]+0.5,p["y"]+0.5) for p in poly]
            poly = [p for x in poly for p in x]
            obj = {
                "bbox": [np.min(px), np.min(py), np.max(px), np.max(py)],
                "bbox_mode": BoxMode.XYXY_ABS,
                "segmentation": [poly],
                "category_id": 0,
            }
        
            objs.append(obj)
        record["annotations"] = objs
        dataset_dicts.append(record)
    return dataset_dicts

# %%
DatasetCatalog.register("rock_" + "train",lambda: get_rock_dicts(image_dir="Dataset",json_dir="rock-darwin"))
MetadataCatalog.get("rock_" + "train").set(thing_classes=["rock"])
rock_metadata = MetadataCatalog.get("rock_train")

# %%
dataset_dicts = get_rock_dicts(image_dir="Dataset",json_dir="rock-darwin")

# %%
for d in random.sample(dataset_dicts, 1):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=rock_metadata, scale=0.5)
    vis = visualizer.draw_dataset_dict(d)
    plt.imshow(vis.get_image()[:, :, ::-1])

# %%
import warnings
warnings.filterwarnings("ignore")
from PIL import ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

cfg = get_cfg()
cfg.MODEL.DEVICE='cpu'
#cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("rock_train",)
cfg.DATASETS.TEST = ()
cfg.DATALOADER.NUM_WORKERS =2
#cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2
#cfg.INPUT.MIN_SIZE_TRAIN=(800,)
cfg.SOLVER.BASE_LR = 1e-4  # pick a good LR
cfg.SOLVER.MAX_ITER = 2000 # 300 iterations seems good enough for this toy dataset; you may need to train longer for a practical dataset
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128  # faster, and good enough for this toy dataset (default: 512)
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1  # only has one class (rock)
os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [06/10 10:10:19 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (6): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (7): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (8): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (9): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (10): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (11): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (12): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (13): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (14): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (15): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (16): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (17): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (18): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (19): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (20): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (21): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (22): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             1024, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             2048, 2048, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=4, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (predictor): Conv2d(256, 1, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# [06/10 10:10:33 d2.data.build]: Removed 1 images with no usable annotations. 344 images left.
# [06/10 10:10:33 d2.data.build]: Distribution of instances among all 1 categories:
# |  category  | #instances   |
# |:----------:|:-------------|
# |    rock    | 376          |
# |            |              |
# [06/10 10:10:33 d2.data.common]: Serializing 344 elements to byte tensors and concatenating them all ...
# [06/10 10:10:33 d2.data.common]: Serialized dataset takes 4.34 MiB
# [06/10 10:10:33 d2.data.detection_utils]: TransformGens used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [06/10 10:10:33 d2.data.build]: Using training sampler TrainingSampler
# Unable to load 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (2, 1024) in the model!
# Unable to load 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (2,) in the model!
# Unable to load 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (4, 1024) in the model!
# Unable to load 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (4,) in the model!
# Unable to load 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (1, 256, 1, 1) in the model!
# Unable to load 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (1,) in the model!
# [06/10 10:10:35 d2.engine.train_loop]: Starting training from iteration 0
# [06/10 10:17:14 d2.utils.events]:  eta: 10:45:06  iter: 19  total_loss: 2.022  loss_cls: 0.877  loss_box_reg: 0.440  loss_mask: 0.693  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 20.0148  data_time: 0.0169  lr: 0.000002  max_mem: 0M
# [06/10 10:23:21 d2.utils.events]:  eta: 10:28:43  iter: 39  total_loss: 1.909  loss_cls: 0.817  loss_box_reg: 0.397  loss_mask: 0.676  loss_rpn_cls: 0.001  loss_rpn_loc: 0.006  time: 19.1311  data_time: 0.0091  lr: 0.000004  max_mem: 0M
# [06/10 10:29:51 d2.utils.events]:  eta: 10:22:18  iter: 59  total_loss: 1.772  loss_cls: 0.698  loss_box_reg: 0.394  loss_mask: 0.653  loss_rpn_cls: 0.002  loss_rpn_loc: 0.010  time: 19.2674  data_time: 0.0104  lr: 0.000006  max_mem: 0M
# [06/10 10:36:15 d2.utils.events]:  eta: 9:59:39  iter: 79  total_loss: 1.660  loss_cls: 0.571  loss_box_reg: 0.483  loss_mask: 0.604  loss_rpn_cls: 0.003  loss_rpn_loc: 0.008  time: 19.2497  data_time: 0.0121  lr: 0.000008  max_mem: 0M
# [06/10 10:42:58 d2.utils.events]:  eta: 10:05:58  iter: 99  total_loss: 1.439  loss_cls: 0.432  loss_box_reg: 0.441  loss_mask: 0.572  loss_rpn_cls: 0.000  loss_rpn_loc: 0.008  time: 19.4268  data_time: 0.0091  lr: 0.000010  max_mem: 0M
# [06/10 10:49:26 d2.utils.events]:  eta: 10:00:57  iter: 119  total_loss: 1.221  loss_cls: 0.346  loss_box_reg: 0.346  loss_mask: 0.508  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 19.4268  data_time: 0.0132  lr: 0.000012  max_mem: 0M
# [06/10 10:55:38 d2.utils.events]:  eta: 9:52:33  iter: 139  total_loss: 1.192  loss_cls: 0.287  loss_box_reg: 0.428  loss_mask: 0.460  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 19.3090  data_time: 0.0118  lr: 0.000014  max_mem: 0M
# [06/10 11:01:47 d2.utils.events]:  eta: 9:42:44  iter: 159  total_loss: 1.143  loss_cls: 0.251  loss_box_reg: 0.434  loss_mask: 0.425  loss_rpn_cls: 0.001  loss_rpn_loc: 0.007  time: 19.1961  data_time: 0.0103  lr: 0.000016  max_mem: 0M
# [06/10 11:07:50 d2.utils.events]:  eta: 9:27:45  iter: 179  total_loss: 1.030  loss_cls: 0.220  loss_box_reg: 0.431  loss_mask: 0.366  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 19.0782  data_time: 0.0106  lr: 0.000018  max_mem: 0M
# [06/10 11:14:31 d2.utils.events]:  eta: 9:26:59  iter: 199  total_loss: 0.938  loss_cls: 0.187  loss_box_reg: 0.421  loss_mask: 0.307  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 19.1748  data_time: 0.0150  lr: 0.000020  max_mem: 0M
# [06/10 11:20:07 d2.utils.events]:  eta: 9:12:22  iter: 219  total_loss: 0.890  loss_cls: 0.175  loss_box_reg: 0.410  loss_mask: 0.288  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.9601  data_time: 0.0082  lr: 0.000022  max_mem: 0M
# [06/10 11:26:28 d2.utils.events]:  eta: 9:10:58  iter: 239  total_loss: 0.865  loss_cls: 0.166  loss_box_reg: 0.436  loss_mask: 0.242  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.9657  data_time: 0.0089  lr: 0.000024  max_mem: 0M
# [06/10 11:32:40 d2.utils.events]:  eta: 9:00:43  iter: 259  total_loss: 0.824  loss_cls: 0.160  loss_box_reg: 0.395  loss_mask: 0.216  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.9395  data_time: 0.0116  lr: 0.000026  max_mem: 0M
# [06/10 11:38:43 d2.utils.events]:  eta: 8:54:30  iter: 279  total_loss: 0.737  loss_cls: 0.126  loss_box_reg: 0.433  loss_mask: 0.172  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8817  data_time: 0.0120  lr: 0.000028  max_mem: 0M
# [06/10 11:45:12 d2.utils.events]:  eta: 8:48:53  iter: 299  total_loss: 0.673  loss_cls: 0.105  loss_box_reg: 0.401  loss_mask: 0.167  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.9182  data_time: 0.0104  lr: 0.000030  max_mem: 0M
# [06/10 11:51:24 d2.utils.events]:  eta: 8:44:24  iter: 319  total_loss: 0.575  loss_cls: 0.090  loss_box_reg: 0.340  loss_mask: 0.133  loss_rpn_cls: 0.000  loss_rpn_loc: 0.008  time: 18.8982  data_time: 0.0102  lr: 0.000032  max_mem: 0M
# [06/10 11:57:27 d2.utils.events]:  eta: 8:38:10  iter: 339  total_loss: 0.592  loss_cls: 0.083  loss_box_reg: 0.368  loss_mask: 0.120  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.8553  data_time: 0.0102  lr: 0.000034  max_mem: 0M
# [06/10 12:04:16 d2.utils.events]:  eta: 8:33:25  iter: 359  total_loss: 0.652  loss_cls: 0.081  loss_box_reg: 0.410  loss_mask: 0.124  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.9428  data_time: 0.0094  lr: 0.000036  max_mem: 0M
# [06/10 12:10:24 d2.utils.events]:  eta: 8:24:21  iter: 379  total_loss: 0.580  loss_cls: 0.077  loss_box_reg: 0.399  loss_mask: 0.086  loss_rpn_cls: 0.000  loss_rpn_loc: 0.008  time: 18.9144  data_time: 0.0105  lr: 0.000038  max_mem: 0M
# [06/10 12:16:34 d2.utils.events]:  eta: 8:18:07  iter: 399  total_loss: 0.557  loss_cls: 0.074  loss_box_reg: 0.382  loss_mask: 0.077  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.8935  data_time: 0.0094  lr: 0.000040  max_mem: 0M
# [06/10 12:23:12 d2.utils.events]:  eta: 8:14:39  iter: 419  total_loss: 0.523  loss_cls: 0.061  loss_box_reg: 0.362  loss_mask: 0.079  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.9413  data_time: 0.0098  lr: 0.000042  max_mem: 0M
# [06/10 12:29:23 d2.utils.events]:  eta: 8:07:08  iter: 439  total_loss: 0.412  loss_cls: 0.043  loss_box_reg: 0.294  loss_mask: 0.069  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.9237  data_time: 0.0093  lr: 0.000044  max_mem: 0M
# [06/10 12:35:34 d2.utils.events]:  eta: 8:01:07  iter: 459  total_loss: 0.475  loss_cls: 0.049  loss_box_reg: 0.331  loss_mask: 0.060  loss_rpn_cls: 0.000  loss_rpn_loc: 0.008  time: 18.9068  data_time: 0.0094  lr: 0.000046  max_mem: 0M
# [06/10 12:41:49 d2.utils.events]:  eta: 7:53:53  iter: 479  total_loss: 0.445  loss_cls: 0.050  loss_box_reg: 0.309  loss_mask: 0.058  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8993  data_time: 0.0109  lr: 0.000048  max_mem: 0M
# [06/10 12:47:45 d2.utils.events]:  eta: 7:47:39  iter: 499  total_loss: 0.351  loss_cls: 0.040  loss_box_reg: 0.229  loss_mask: 0.053  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.8570  data_time: 0.0087  lr: 0.000050  max_mem: 0M
# [06/10 12:53:52 d2.utils.events]:  eta: 7:41:25  iter: 519  total_loss: 0.230  loss_cls: 0.039  loss_box_reg: 0.141  loss_mask: 0.045  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.8361  data_time: 0.0115  lr: 0.000052  max_mem: 0M
# [06/10 13:00:31 d2.utils.events]:  eta: 7:36:08  iter: 539  total_loss: 0.261  loss_cls: 0.030  loss_box_reg: 0.153  loss_mask: 0.045  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.8784  data_time: 0.0086  lr: 0.000054  max_mem: 0M
# [06/10 13:06:16 d2.utils.events]:  eta: 7:28:30  iter: 559  total_loss: 0.291  loss_cls: 0.036  loss_box_reg: 0.175  loss_mask: 0.044  loss_rpn_cls: 0.000  loss_rpn_loc: 0.008  time: 18.8199  data_time: 0.0100  lr: 0.000056  max_mem: 0M
# [06/10 13:12:52 d2.utils.events]:  eta: 7:22:34  iter: 579  total_loss: 0.227  loss_cls: 0.034  loss_box_reg: 0.106  loss_mask: 0.043  loss_rpn_cls: 0.000  loss_rpn_loc: 0.009  time: 18.8530  data_time: 0.0101  lr: 0.000058  max_mem: 0M
# [06/10 13:18:52 d2.utils.events]:  eta: 7:15:31  iter: 599  total_loss: 0.249  loss_cls: 0.033  loss_box_reg: 0.174  loss_mask: 0.041  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8238  data_time: 0.0103  lr: 0.000060  max_mem: 0M
# [06/10 13:24:46 d2.utils.events]:  eta: 7:08:58  iter: 619  total_loss: 0.185  loss_cls: 0.031  loss_box_reg: 0.112  loss_mask: 0.039  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7879  data_time: 0.0098  lr: 0.000062  max_mem: 0M
# [06/10 13:30:49 d2.utils.events]:  eta: 7:02:40  iter: 639  total_loss: 0.206  loss_cls: 0.025  loss_box_reg: 0.125  loss_mask: 0.039  loss_rpn_cls: 0.000  loss_rpn_loc: 0.009  time: 18.7687  data_time: 0.0107  lr: 0.000064  max_mem: 0M
# [06/10 13:37:12 d2.utils.events]:  eta: 6:56:34  iter: 659  total_loss: 0.216  loss_cls: 0.030  loss_box_reg: 0.129  loss_mask: 0.039  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.7794  data_time: 0.0100  lr: 0.000066  max_mem: 0M
# [06/10 13:43:19 d2.utils.events]:  eta: 6:50:15  iter: 679  total_loss: 0.182  loss_cls: 0.031  loss_box_reg: 0.108  loss_mask: 0.040  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.7674  data_time: 0.0081  lr: 0.000068  max_mem: 0M
# [06/10 13:49:24 d2.utils.events]:  eta: 6:43:38  iter: 699  total_loss: 0.163  loss_cls: 0.025  loss_box_reg: 0.088  loss_mask: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.7518  data_time: 0.0097  lr: 0.000070  max_mem: 0M
# [06/10 13:55:45 d2.utils.events]:  eta: 6:37:39  iter: 719  total_loss: 0.176  loss_cls: 0.031  loss_box_reg: 0.090  loss_mask: 0.038  loss_rpn_cls: 0.000  loss_rpn_loc: 0.007  time: 18.7603  data_time: 0.0106  lr: 0.000072  max_mem: 0M
# [06/10 14:01:40 d2.utils.events]:  eta: 6:31:13  iter: 739  total_loss: 0.151  loss_cls: 0.024  loss_box_reg: 0.080  loss_mask: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.7321  data_time: 0.0102  lr: 0.000074  max_mem: 0M
# [06/10 14:08:00 d2.utils.events]:  eta: 6:25:16  iter: 759  total_loss: 0.150  loss_cls: 0.030  loss_box_reg: 0.083  loss_mask: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7402  data_time: 0.0113  lr: 0.000076  max_mem: 0M
# [06/10 14:14:12 d2.utils.events]:  eta: 6:18:49  iter: 779  total_loss: 0.152  loss_cls: 0.029  loss_box_reg: 0.082  loss_mask: 0.032  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.7358  data_time: 0.0092  lr: 0.000078  max_mem: 0M
# [06/10 14:20:19 d2.utils.events]:  eta: 6:12:16  iter: 799  total_loss: 0.167  loss_cls: 0.026  loss_box_reg: 0.096  loss_mask: 0.035  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.7258  data_time: 0.0106  lr: 0.000080  max_mem: 0M
# [06/10 14:26:34 d2.utils.events]:  eta: 6:05:36  iter: 819  total_loss: 0.136  loss_cls: 0.019  loss_box_reg: 0.061  loss_mask: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7269  data_time: 0.0092  lr: 0.000082  max_mem: 0M
# [06/10 14:32:49 d2.utils.events]:  eta: 5:59:11  iter: 839  total_loss: 0.139  loss_cls: 0.024  loss_box_reg: 0.066  loss_mask: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.7272  data_time: 0.0092  lr: 0.000084  max_mem: 0M
# [06/10 14:39:01 d2.utils.events]:  eta: 5:52:58  iter: 859  total_loss: 0.161  loss_cls: 0.020  loss_box_reg: 0.084  loss_mask: 0.036  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7241  data_time: 0.0083  lr: 0.000086  max_mem: 0M
# [06/10 14:45:44 d2.utils.events]:  eta: 5:47:02  iter: 879  total_loss: 0.136  loss_cls: 0.024  loss_box_reg: 0.067  loss_mask: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.7563  data_time: 0.0108  lr: 0.000088  max_mem: 0M
# [06/10 14:52:12 d2.utils.events]:  eta: 5:41:35  iter: 899  total_loss: 0.145  loss_cls: 0.024  loss_box_reg: 0.067  loss_mask: 0.032  loss_rpn_cls: 0.000  loss_rpn_loc: 0.008  time: 18.7712  data_time: 0.0086  lr: 0.000090  max_mem: 0M
# [06/10 14:58:47 d2.utils.events]:  eta: 5:35:36  iter: 919  total_loss: 0.133  loss_cls: 0.028  loss_box_reg: 0.061  loss_mask: 0.033  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7926  data_time: 0.0080  lr: 0.000092  max_mem: 0M
# [06/10 15:04:41 d2.utils.events]:  eta: 5:28:53  iter: 939  total_loss: 0.120  loss_cls: 0.022  loss_box_reg: 0.057  loss_mask: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.7688  data_time: 0.0096  lr: 0.000094  max_mem: 0M
# [06/10 15:10:47 d2.utils.events]:  eta: 5:22:02  iter: 959  total_loss: 0.114  loss_cls: 0.016  loss_box_reg: 0.053  loss_mask: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.7592  data_time: 0.0103  lr: 0.000096  max_mem: 0M
# [06/10 15:16:59 d2.utils.events]:  eta: 5:15:47  iter: 979  total_loss: 0.103  loss_cls: 0.016  loss_box_reg: 0.052  loss_mask: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.7560  data_time: 0.0104  lr: 0.000098  max_mem: 0M
# [06/10 15:23:29 d2.utils.events]:  eta: 5:09:40  iter: 999  total_loss: 0.110  loss_cls: 0.020  loss_box_reg: 0.054  loss_mask: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.007  time: 18.7703  data_time: 0.0121  lr: 0.000100  max_mem: 0M
# [06/10 15:29:44 d2.utils.events]:  eta: 5:03:16  iter: 1019  total_loss: 0.119  loss_cls: 0.020  loss_box_reg: 0.059  loss_mask: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7698  data_time: 0.0112  lr: 0.000100  max_mem: 0M
# [06/10 15:35:57 d2.utils.events]:  eta: 4:57:02  iter: 1039  total_loss: 0.106  loss_cls: 0.017  loss_box_reg: 0.051  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7655  data_time: 0.0088  lr: 0.000100  max_mem: 0M
# [06/10 15:42:06 d2.utils.events]:  eta: 4:50:43  iter: 1059  total_loss: 0.117  loss_cls: 0.023  loss_box_reg: 0.062  loss_mask: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.7595  data_time: 0.0110  lr: 0.000100  max_mem: 0M
# [06/10 15:48:47 d2.utils.events]:  eta: 4:44:32  iter: 1079  total_loss: 0.107  loss_cls: 0.020  loss_box_reg: 0.048  loss_mask: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.007  time: 18.7831  data_time: 0.0098  lr: 0.000100  max_mem: 0M
# [06/10 15:55:28 d2.utils.events]:  eta: 4:38:15  iter: 1099  total_loss: 0.106  loss_cls: 0.019  loss_box_reg: 0.053  loss_mask: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8064  data_time: 0.0100  lr: 0.000100  max_mem: 0M
# [06/10 16:01:52 d2.utils.events]:  eta: 4:32:01  iter: 1119  total_loss: 0.111  loss_cls: 0.022  loss_box_reg: 0.051  loss_mask: 0.030  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8132  data_time: 0.0101  lr: 0.000100  max_mem: 0M
# [06/10 16:08:31 d2.utils.events]:  eta: 4:26:07  iter: 1139  total_loss: 0.093  loss_cls: 0.018  loss_box_reg: 0.047  loss_mask: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8334  data_time: 0.0097  lr: 0.000100  max_mem: 0M
# [06/10 16:15:16 d2.utils.events]:  eta: 4:20:10  iter: 1159  total_loss: 0.111  loss_cls: 0.018  loss_box_reg: 0.048  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8577  data_time: 0.0085  lr: 0.000100  max_mem: 0M
# [06/10 16:21:56 d2.utils.events]:  eta: 4:14:43  iter: 1179  total_loss: 0.099  loss_cls: 0.016  loss_box_reg: 0.046  loss_mask: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8767  data_time: 0.0108  lr: 0.000100  max_mem: 0M
# [06/10 16:29:25 d2.utils.events]:  eta: 4:07:48  iter: 1199  total_loss: 0.122  loss_cls: 0.021  loss_box_reg: 0.056  loss_mask: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.9362  data_time: 0.0124  lr: 0.000100  max_mem: 0M
# [06/10 16:35:20 d2.utils.events]:  eta: 4:02:01  iter: 1219  total_loss: 0.109  loss_cls: 0.024  loss_box_reg: 0.047  loss_mask: 0.029  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.9172  data_time: 0.0089  lr: 0.000100  max_mem: 0M
# [06/10 16:40:42 d2.utils.events]:  eta: 3:55:06  iter: 1239  total_loss: 0.100  loss_cls: 0.016  loss_box_reg: 0.049  loss_mask: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.8712  data_time: 0.0091  lr: 0.000100  max_mem: 0M
# [06/10 16:46:14 d2.utils.events]:  eta: 3:48:39  iter: 1259  total_loss: 0.101  loss_cls: 0.017  loss_box_reg: 0.043  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8352  data_time: 0.0099  lr: 0.000100  max_mem: 0M
# [06/10 16:52:42 d2.utils.events]:  eta: 3:42:40  iter: 1279  total_loss: 0.103  loss_cls: 0.018  loss_box_reg: 0.050  loss_mask: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.8439  data_time: 0.0097  lr: 0.000100  max_mem: 0M
# [06/10 17:00:38 d2.utils.events]:  eta: 3:36:38  iter: 1299  total_loss: 0.119  loss_cls: 0.020  loss_box_reg: 0.046  loss_mask: 0.031  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.9205  data_time: 0.0115  lr: 0.000100  max_mem: 0M
# [06/10 17:06:31 d2.utils.events]:  eta: 3:30:16  iter: 1319  total_loss: 0.094  loss_cls: 0.017  loss_box_reg: 0.038  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.9012  data_time: 0.0120  lr: 0.000100  max_mem: 0M
# [06/10 17:11:49 d2.utils.events]:  eta: 3:23:14  iter: 1339  total_loss: 0.087  loss_cls: 0.014  loss_box_reg: 0.036  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.8564  data_time: 0.0078  lr: 0.000100  max_mem: 0M
# [06/10 17:17:35 d2.utils.events]:  eta: 3:16:21  iter: 1359  total_loss: 0.089  loss_cls: 0.021  loss_box_reg: 0.042  loss_mask: 0.024  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.8329  data_time: 0.0115  lr: 0.000100  max_mem: 0M
# [06/10 17:23:20 d2.utils.events]:  eta: 3:10:11  iter: 1379  total_loss: 0.104  loss_cls: 0.019  loss_box_reg: 0.047  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.8101  data_time: 0.0081  lr: 0.000100  max_mem: 0M
# [06/10 17:29:18 d2.utils.events]:  eta: 3:03:50  iter: 1399  total_loss: 0.090  loss_cls: 0.018  loss_box_reg: 0.040  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.7973  data_time: 0.0102  lr: 0.000100  max_mem: 0M
# [06/10 17:35:29 d2.utils.events]:  eta: 2:57:35  iter: 1419  total_loss: 0.089  loss_cls: 0.016  loss_box_reg: 0.039  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.7934  data_time: 0.0096  lr: 0.000100  max_mem: 0M
# [06/10 17:42:01 d2.utils.events]:  eta: 2:51:30  iter: 1439  total_loss: 0.100  loss_cls: 0.017  loss_box_reg: 0.043  loss_mask: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.8045  data_time: 0.0148  lr: 0.000100  max_mem: 0M
# [06/10 17:47:58 d2.utils.events]:  eta: 2:45:22  iter: 1459  total_loss: 0.099  loss_cls: 0.015  loss_box_reg: 0.043  loss_mask: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.7919  data_time: 0.0100  lr: 0.000100  max_mem: 0M
# [06/10 17:54:00 d2.utils.events]:  eta: 2:39:14  iter: 1479  total_loss: 0.099  loss_cls: 0.016  loss_box_reg: 0.046  loss_mask: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7824  data_time: 0.0085  lr: 0.000100  max_mem: 0M
# [06/10 18:00:21 d2.utils.events]:  eta: 2:33:06  iter: 1499  total_loss: 0.076  loss_cls: 0.013  loss_box_reg: 0.038  loss_mask: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.7860  data_time: 0.0092  lr: 0.000100  max_mem: 0M
# [06/10 18:06:35 d2.utils.events]:  eta: 2:27:03  iter: 1519  total_loss: 0.088  loss_cls: 0.010  loss_box_reg: 0.041  loss_mask: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7845  data_time: 0.0099  lr: 0.000100  max_mem: 0M
# [06/10 18:12:44 d2.utils.events]:  eta: 2:20:55  iter: 1539  total_loss: 0.083  loss_cls: 0.014  loss_box_reg: 0.037  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.7802  data_time: 0.0089  lr: 0.000100  max_mem: 0M
# [06/10 18:19:19 d2.utils.events]:  eta: 2:15:04  iter: 1559  total_loss: 0.120  loss_cls: 0.016  loss_box_reg: 0.046  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.008  time: 18.7928  data_time: 0.0072  lr: 0.000100  max_mem: 0M
# [06/10 18:25:31 d2.utils.events]:  eta: 2:08:39  iter: 1579  total_loss: 0.080  loss_cls: 0.013  loss_box_reg: 0.036  loss_mask: 0.024  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.7899  data_time: 0.0070  lr: 0.000100  max_mem: 0M
# [06/10 18:31:47 d2.utils.events]:  eta: 2:02:38  iter: 1599  total_loss: 0.085  loss_cls: 0.016  loss_box_reg: 0.039  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.7901  data_time: 0.0094  lr: 0.000100  max_mem: 0M
# [06/10 18:38:21 d2.utils.events]:  eta: 1:56:42  iter: 1619  total_loss: 0.088  loss_cls: 0.017  loss_box_reg: 0.038  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.8013  data_time: 0.0125  lr: 0.000100  max_mem: 0M
# [06/10 18:44:46 d2.utils.events]:  eta: 1:50:40  iter: 1639  total_loss: 0.077  loss_cls: 0.014  loss_box_reg: 0.040  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.002  time: 18.8069  data_time: 0.0079  lr: 0.000100  max_mem: 0M
# [06/10 18:52:01 d2.utils.events]:  eta: 1:44:34  iter: 1659  total_loss: 0.105  loss_cls: 0.015  loss_box_reg: 0.043  loss_mask: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8426  data_time: 0.0094  lr: 0.000100  max_mem: 0M
# [06/10 18:57:42 d2.utils.events]:  eta: 1:38:27  iter: 1679  total_loss: 0.076  loss_cls: 0.012  loss_box_reg: 0.036  loss_mask: 0.024  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.8208  data_time: 0.0079  lr: 0.000100  max_mem: 0M
# [06/10 19:03:12 d2.utils.events]:  eta: 1:32:11  iter: 1699  total_loss: 0.082  loss_cls: 0.011  loss_box_reg: 0.039  loss_mask: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7935  data_time: 0.0079  lr: 0.000100  max_mem: 0M
# [06/10 19:08:19 d2.utils.events]:  eta: 1:25:43  iter: 1719  total_loss: 0.101  loss_cls: 0.020  loss_box_reg: 0.045  loss_mask: 0.027  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7538  data_time: 0.0091  lr: 0.000100  max_mem: 0M
# [06/10 19:14:01 d2.utils.events]:  eta: 1:19:23  iter: 1739  total_loss: 0.087  loss_cls: 0.015  loss_box_reg: 0.041  loss_mask: 0.028  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7342  data_time: 0.0085  lr: 0.000100  max_mem: 0M
# [06/10 19:19:24 d2.utils.events]:  eta: 1:13:00  iter: 1759  total_loss: 0.082  loss_cls: 0.014  loss_box_reg: 0.040  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.7051  data_time: 0.0073  lr: 0.000100  max_mem: 0M
# [06/10 19:24:20 d2.utils.events]:  eta: 1:06:42  iter: 1779  total_loss: 0.077  loss_cls: 0.012  loss_box_reg: 0.036  loss_mask: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.6612  data_time: 0.0079  lr: 0.000100  max_mem: 0M
# [06/10 19:30:20 d2.utils.events]:  eta: 1:00:41  iter: 1799  total_loss: 0.099  loss_cls: 0.015  loss_box_reg: 0.047  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.005  time: 18.6538  data_time: 0.0090  lr: 0.000100  max_mem: 0M
# [06/10 19:36:46 d2.utils.events]:  eta: 0:54:41  iter: 1819  total_loss: 0.075  loss_cls: 0.011  loss_box_reg: 0.036  loss_mask: 0.024  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.6606  data_time: 0.0124  lr: 0.000100  max_mem: 0M
# [06/10 19:43:11 d2.utils.events]:  eta: 0:48:40  iter: 1839  total_loss: 0.079  loss_cls: 0.010  loss_box_reg: 0.035  loss_mask: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.008  time: 18.6674  data_time: 0.0071  lr: 0.000100  max_mem: 0M
# [06/10 19:49:51 d2.utils.events]:  eta: 0:42:44  iter: 1859  total_loss: 0.092  loss_cls: 0.016  loss_box_reg: 0.045  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.6814  data_time: 0.0094  lr: 0.000100  max_mem: 0M
# [06/10 19:57:29 d2.utils.events]:  eta: 0:36:44  iter: 1879  total_loss: 0.082  loss_cls: 0.012  loss_box_reg: 0.035  loss_mask: 0.022  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7266  data_time: 0.0137  lr: 0.000100  max_mem: 0M
# [06/10 20:03:58 d2.utils.events]:  eta: 0:30:39  iter: 1899  total_loss: 0.083  loss_cls: 0.016  loss_box_reg: 0.035  loss_mask: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7338  data_time: 0.0107  lr: 0.000100  max_mem: 0M
# [06/10 20:09:26 d2.utils.events]:  eta: 0:24:28  iter: 1919  total_loss: 0.085  loss_cls: 0.012  loss_box_reg: 0.039  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.7095  data_time: 0.0071  lr: 0.000100  max_mem: 0M
# [06/10 20:15:10 d2.utils.events]:  eta: 0:18:26  iter: 1939  total_loss: 0.085  loss_cls: 0.013  loss_box_reg: 0.039  loss_mask: 0.025  loss_rpn_cls: 0.000  loss_rpn_loc: 0.006  time: 18.6940  data_time: 0.0078  lr: 0.000100  max_mem: 0M
# [06/10 20:20:55 d2.utils.events]:  eta: 0:12:22  iter: 1959  total_loss: 0.095  loss_cls: 0.011  loss_box_reg: 0.037  loss_mask: 0.022  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.6793  data_time: 0.0080  lr: 0.000100  max_mem: 0M
# [06/10 20:26:31 d2.utils.events]:  eta: 0:06:20  iter: 1979  total_loss: 0.091  loss_cls: 0.021  loss_box_reg: 0.038  loss_mask: 0.026  loss_rpn_cls: 0.000  loss_rpn_loc: 0.004  time: 18.6602  data_time: 0.0111  lr: 0.000100  max_mem: 0M
# [06/10 20:32:20 d2.utils.events]:  eta: 0:00:18  iter: 1999  total_loss: 0.087  loss_cls: 0.012  loss_box_reg: 0.036  loss_mask: 0.023  loss_rpn_cls: 0.000  loss_rpn_loc: 0.003  time: 18.6478  data_time: 0.0091  lr: 0.000100  max_mem: 0M
# [06/10 20:32:20 d2.engine.hooks]: Overall training speed: 1997 iterations in 10:20:58 (18.6572 s / it)
# [06/10 20:32:20 d2.engine.hooks]: Total training time: 10:21:04 (0:00:05 on hooks)

# %%
cfg = get_cfg()
cfg.MODEL.DEVICE='cpu'
cfg.OUTPUT_DIR="RockNet-segmentation/trained-X101" #best model
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x.yaml"))
#cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 1 
cfg.MODEL.WEIGHTS = os.path.join(cfg.OUTPUT_DIR, "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 1
#cfg.DATASETS.TEST = ("rock_val", )
predictor = DefaultPredictor(cfg)

# %%
def diff(dir1,dir2):
    folder1=os.listdir(dir1)
    folder2=os.listdir(dir2)
    folder3 = [name for name in folder1 if name not in folder2]
    return folder3

# %%
def predict(input_folder,save_folder):
    dir1=input_folder
    dir2="RockNet/PascalVOC800/JPEGImages"
    filenames = diff(dir1,dir2)
    print(" {} contient {} images".format(dir1,len(os.listdir(dir1))))
    #filenames=os.listdir(input_folder)
    print("Prédictions pour {} images...".format(len(filenames)))
    for i in range(len(filenames)):
        image_path=os.path.join(input_folder,filenames[i])
        try:
            im=cv2.imread(image_path)
            outputs = predictor(im)
            v = Visualizer(im[:, :, ::-1],
                   metadata=rock_metadata, 
                   scale=0.8, 
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels
    )
            v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
            name=filenames[i]
            outpout_name=name[:-4]+"prediction.jpg"
            outpout_name=name[:-4]+".jpg"
            
            im=v.get_image()[:, :, ::-1]
            cv2.imwrite(os.path.join(save_folder,outpout_name), im)
            
        except:
            print(filenames[i],"n'est pas une image")
    
    print("Prédictions terminée")

# %%
predict(input_folder="rock-training-images",save_folder="Test-images")
# Out:
#  rock-training-images contient 892 images
# Prédictions pour 703 images...
# Prédictions terminée

# %%
classes=["rock"]
def create_metric_file(input_folder,output_folder):
    print("Création en cours")
    filenames=os.listdir(input_folder)
    for i in range(len(filenames)):
        try:
            image_path=os.path.join(input_folder,filenames[i])
            output=os.path.join(output_folder,filenames[i])
            file=open(output+".txt",'w')
            im=cv2.imread(image_path)
            outputs = predictor(im)
            instances=outputs["instances"].to("cpu")
            results=instances.get_fields()
            boxes=results["pred_boxes"]
            boxes=np.array(boxes.tensor)
            scores=results['scores']
            pred_classes=results["pred_classes"]
            for j in range(len(boxes)):
                xmin = int(boxes[j][0])
                ymin = int(boxes[j][1])
                xmax = int(boxes[j][2])
                ymax = int(boxes[j][3])
                file.write(classes[pred_classes[j]])
                file.write("\t")
                file.write(str(float(scores[j])))
                file.write("\t")
                file.write(str(int(xmin)))
                file.write("\t")
                file.write(str(int(ymin)))
                file.write("\t")
                file.write(str(int(xmax)))
                file.write("\t")
                file.write(str(int(ymax)))
                file.write("\n")
        except:
            print(filenames[i],"corrompu")
            continue
    print("Terminée")

# %%
create_metric_file(input_folder="Test-images",output_folder="RockNet-segmentation/Object-Detection-Metrics/detections")
# Out:
# Création en cours
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d40962b6a440> in <module>
# ----> 1 create_metric_file(input_folder="Test-images",output_folder="RockNet-segmentation/Object-Detection-Metrics/detections")
#
# <ipython-input-12-c5260f115378> in create_metric_file(input_folder, output_folder)
#       8         file=open(output+".txt",'w')
#       9         im=cv2.imread(image_path)
# ---> 10         outputs = predictor(im)
#      11         instances=outputs["instances"].to("cpu")
#      12         results=instances.get_fields()
#
# /opt/conda/lib/python3.7/site-packages/detectron2/engine/defaults.py in __call__(self, original_image)
#     211                 # whether the model expects BGR inputs or RGB
#     212                 original_image = original_image[:, :, ::-1]
# --> 213             height, width = original_image.shape[:2]
#     214             image = self.transform_gen.get_transform(original_image).apply_image(original_image)
#     215             image = torch.as_tensor(image.astype("float32").transpose(2, 0, 1))
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
cfg.MODEL.DEVICE='cpu'
evaluator = COCOEvaluator("rock_train", cfg, False, output_dir="./output")
val_loader = build_detection_test_loader(cfg, "rock_train")
#inference_on_dataset(trainer.model, val_loader, evaluator)
inference_on_dataset(predictor.model, val_loader, evaluator)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-a0e2994e00c2> in <module>
#       5 val_loader = build_detection_test_loader(cfg, "rock_train")
#       6 #inference_on_dataset(trainer.model, val_loader, evaluator)
# ----> 7 inference_on_dataset(predictor.model, val_loader, evaluator)
#
# /opt/conda/lib/python3.7/site-packages/detectron2/evaluation/evaluator.py in inference_on_dataset(model, data_loader, evaluator)
#     141             outputs = model(inputs)
#     142             if torch.cuda.is_available():
# --> 143                 torch.cuda.synchronize()
#     144             total_compute_time += time.perf_counter() - start_compute_time
#     145             evaluator.process(inputs, outputs)
#
# /opt/conda/lib/python3.7/site-packages/torch/cuda/__init__.py in synchronize(device)
#     342     _lazy_init()
#     343     with torch.cuda.device(device):
# --> 344         return torch._C._cuda_synchronize()
#     345
#     346
#
# RuntimeError: cuda runtime error (2) : out of memory at /opt/conda/conda-bld/pytorch_1587428398394/work/torch/csrc/cuda/Module.cpp:207
